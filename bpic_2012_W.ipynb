# %% [markdown]
# ### **BPIC 2012 - No milestone**

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from data.processor import *
from data.args import *

from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### Define the experiment parameters

# %%
milestone = 'All' #'A_PREACCEPTED' # 'W_Nabellen offertes', 'All'
subset = "W"
experiment =  'OHE'#'Standard'#'OHE', 'No_loops'
n_size = 5
max_size = 1000 #  3, 5, 10, 15, 20, 30, 50, 95
min_size = 0  # 0, 3, 5, 10, 15, 20, 30, 50

# %% [markdown]
# ### Setting up the key parameters

# %%
# # For local environment only

MY_WORKSPACE_DIR = os.path.join(os.getcwd(),'BPIC12')
MILESTONE_DIR = os.path.join(os.path.join(MY_WORKSPACE_DIR, milestone),experiment)

# %%
args = get_parameters('bpic12', MILESTONE_DIR, MY_WORKSPACE_DIR, milestone, experiment,n_size)
args
# Out:
# {'folder': 'c:\\Users\\20182009\\Documents\\Master DSAI\\y2 q1\\2IMI00 seminar process analytics\\replicationStudy\\Shared-and-Specialised-Attention-based-Interpretable-Models\\BPIC12\\All\\OHE\\output_files',
#  'lstm_act': None,
#  'dense_act': None,
#  'optim': 'Adam',
#  'norm_method': 'lognorm',
#  'model_type': 'shared_cat',
#  'l_size': 50,
#  'n_size': 5,
#  'file_name': 'c:\\Users\\20182009\\Documents\\Master DSAI\\y2 q1\\2IMI00 seminar process analytics\\replicationStudy\\Shared-and-Specialised-Attention-based-Interpretable-Models\\BPIC12\\BPIC_2012_Prefixes.csv',
#  'file_name_all': 'c:\\Users\\20182009\\Documents\\Master DSAI\\y2 q1\\2IMI00 seminar process analytics\\replicationStudy\\Shared-and-Specialised-Attention-based-Interpretable-Models\\BPIC12\\BPIC_2012_Prefixes_all.csv',
#  'processed_file_name': 'c:\\Users\\20182009\\Documents\\Master DSAI\\y2 q1\\2IMI00 seminar process analytics\\replicationStudy\\Shared-and-Specialised-Attention-based-Interpretable-Models\\BPIC12\\All\\OHE\\BPIC_2012_Processed.csv',
#  'processed_training_vec': 'c:\\Users\\20182009\\Documents\\Master DSAI\\y2 q1\\2IMI00 seminar process analytics\\replicationStudy\\Shared-and-Specialised-Attention-based-Interpretable-Models\\BPIC12\\All\\OHE\\vec_training.p',
#  'processed_test_vec': 'c:\\Users\\20182009\\Documents\\Master DSAI\\y2 q1\\2IMI00 seminar process analytics\\replicationStudy\\Shared-and-Specialised-Attention-based-Interpretable-Models\\BPIC12\\All\\OHE\\vec_test.p',
#  'processed_val_vec': 'c:\\Users\\20182009\\Documents\\Master DSAI\\y2 q1\\2IMI00 seminar process analytics\\replicationStudy\\Shared-and-Specialised-Attention-based-Interpretable-Models\\BPIC12\\All\\OHE\\vec_val.p',
#  'weights': 'c:\\Users\\20182009\\Documents\\Master DSAI\\y2 q1\\2IMI00 seminar process analytics\\replicationStudy\\Shared-and-Specialised-Attention-based-Interpretable-Models\\BPIC12\\All\\OHE\\weights.p',
#  'indexes': 'c:\\Users\\20182009\\Documents\\Master DSAI\\y2 q1\\2IMI00 seminar process analytics\\replicationStudy\\Shared-and-Specialised-Attention-based-Interpretable-Models\\BPIC12\\All\\OHE\\indexes.p',
#  'pre_index': 'c:\\Users\\20182009\\Documents\\Master DSAI\\y2 q1\\2IMI00 seminar process analytics\\replicationStudy\\Shared-and-Specialised-Attention-based-Interpretable-Models\\BPIC12\\All\\OHE\\pre_index.p',
#  'args': 'c:\\Users\\20182009\\Documents\\Master DSAI\\y2 q1\\2IMI00 seminar process analytics\\replicationStudy\\Shared-and-Specialised-Attention-based-Interpretable-Models\\BPIC12\\All\\OHE\\args.p',
#  'milestone': 'All',
#  'experiment': 'OHE',
#  'prefix_length': 'fixed',
#  'log_name': 'bpic12'}

# %%
#This code will be specific for all next activity prediction only, since we save the models and vectors by prefix length groups
# if milestone == 'All':
#   args['indexes'] = MILESTONE_DIR+'indexes_'+str(max_size)+'.p'
#   args['pre_index'] = MILESTONE_DIR+'pre_index_'+str(max_size)+'.p'
#   args['processed_test_vec'] = MILESTONE_DIR+'vec_test_'+str(max_size)+'.p'
#   args['processed_training_vec'] = MILESTONE_DIR+'vec_training_'+str(max_size)+'.p'
#   args['weights'] = MILESTONE_DIR+'weights_'+str(max_size)+'.p'

args['file_name_A_ex'] = os.path.join(os.path.join(MY_WORKSPACE_DIR, "Translated_dataset"), "bpic12_translated_completed_A_ex.csv" )
args['file_name_O_ex'] = os.path.join(os.path.join(MY_WORKSPACE_DIR, "Translated_dataset"), "bpic12_translated_completed_O_ex.csv" )
args['file_name_A_all'] = os.path.join(os.path.join(MY_WORKSPACE_DIR, "Translated_dataset"), "bpic12_translated_completed_A_all.csv" )
args['file_name_O_all'] = os.path.join(os.path.join(MY_WORKSPACE_DIR, "Translated_dataset"), "bpic12_translated_completed_O_all.csv" )
args['file_name_W_all'] = os.path.join(os.path.join(MY_WORKSPACE_DIR, "Translated_dataset"), "bpic12_translated_completed_W_all.csv" )

# %% [markdown]
# ###Data Preprocessing

# %%
log_df = pd.read_csv(args['file_name_W_all'])
log_df = log_df.reset_index(drop=True)


log_df.head()
# Out:
#    prefix_id  caseid                                          task  \
# 0   173736_6  173736  W_Filling in information for the application
# 1   173736_4  173736  W_Filling in information for the application
# 2   173736_5  173736  W_Filling in information for the application
# 3  173736_12  173736  W_Filling in information for the application
# 4   173736_1  173736  W_Filling in information for the application
#
#               role                end_timestamp                  trace_start  \
# 0  role_     11019  2011-10-01 23:40:09.6220000  2011-10-01 23:40:09.6220000
# 1  role_     11019  2011-10-01 23:40:09.6220000  2011-10-01 23:40:09.6220000
# 2  role_     11019  2011-10-01 23:40:09.6220000  2011-10-01 23:40:09.6220000
# 3  role_     11019  2011-10-01 23:40:09.6220000  2011-10-01 23:40:09.6220000
# 4  role_     11019  2011-10-01 23:40:09.6220000  2011-10-01 23:40:09.6220000
#
#    timelapsed                                      next_activity  \
# 0           0  W_Calling to add missing information to the ap...
# 1           0                        W_Calling after sent offers
# 2           0                        W_Assessing the application
# 3           0                        W_Assessing the application
# 4           0       W_Filling in information for the application
#
#                                            milestone  milestone_id  \
# 0                        W_Assessing the application             6
# 1                        W_Calling after sent offers             4
# 2                        W_Calling after sent offers             5
# 3  W_Calling to add missing information to the ap...            12
# 4       W_Filling in information for the application             1
#
#    task_index  prefix_length
# 0           1              6
# 1           1              4
# 2           1              5
# 3           1             12
# 4           1              1

# %% [markdown]
# Milestone Extraction
#
# We expect to filter the prefixes by the milestone, and train the model for each milestone separately to observe if there will be an improvement in the model explainability as well as performance

# %%
if milestone != 'All':
  log_df = log_df[log_df['milestone'] == milestone]
else:
  log_df = log_df[(log_df['prefix_length'] > min_size) & (log_df['prefix_length'] <= max_size) ]

# %% [markdown]
# #### Data Analysis

# %%
#Checking the Balance of the Dataset, by the target variable
print('Distribution of cases by the target variable - next event\n')
print(log_df.groupby(['next_activity'])['prefix_id'].nunique())
# Out:
# Distribution of cases by the target variable - next event
#
# next_activity
# W_Assess fraud                                               133
# W_Assessing the application                                 5225
# W_Calling after sent offers                                15621
# W_Calling to add missing information to the application     7615
# W_Filling in information for the application               12967
# W_Fixing incoming lead                                       789
# Name: prefix_id, dtype: int64

# %% [markdown]
# We can see that there is an imbalance in the dataset, by the next activity name, as well as a very high dimensionality in the target variable.
# Therefore, we can reduce the imbalance and high dimensionality of data by grouping some of the activity name.

# %% [markdown]
# Balancing the dataset

# %%
def balance(df):
  # Dictonary with the mapping of columns
  
  #based on the paper : BPIC_2012 Winner, DOI: 10.1007/978-3-642-36285-9_24

  # group_dict = {'A_ACCEPTED':'A_ACCEPTED',    
  #   'A_ACTIVATED' :   'A_APPROVED_ACTIVATED',
  #   'A_APPROVED':  'A_APPROVED_ACTIVATED',
  #   'A_CANCELLED': 'A_CANCELLED_DECLINED' ,
  #   'A_DECLINED': 'A_CANCELLED_DECLINED' ,
  #   'A_PARTLYSUBMITTED': 'REDUNDANT',
  #   'A_PREACCEPTED':'A_PREACCEPTED',
  #   'A_REGISTERED' : 'REDUNDANT',
  #   'O_ACCEPTED' : 'REDUNDANT',
  #   'O_CANCELLED' :  'O_CANCELLED_DECLINED' ,
  #   'O_CREATED':'REDUNDANT',
  #   'O_DECLINED' :'O_CANCELLED_DECLINED' ,
  #   'O_SELECTED' : 'REDUNDANT', 
  #   'O_SENT':'O_SENT',
  #   'O_SENT_BACK' : 'O_SENT_BACK'}


  # df['next_activity'].replace(group_dict, inplace=True)
  # #Dropping the minority classes
  # df = df.drop(df[df.next_activity == 'REDUNDANT'].index)
 

  return df

# %%
log_df = balance(log_df)



#replacing empty cells of categorical columns with 'none'
log_df = log_df.fillna('none')

# %%
# Check the balance

print('Distribution of cases by the target variable - next event\n')
print(log_df.groupby(['next_activity'])['prefix_id'].nunique())
# Out:
# Distribution of cases by the target variable - next event
#
# next_activity
# W_Assess fraud                                               133
# W_Assessing the application                                 5225
# W_Calling after sent offers                                15621
# W_Calling to add missing information to the application     7615
# W_Filling in information for the application               12967
# W_Fixing incoming lead                                       789
# Name: prefix_id, dtype: int64

# %%
#minority reduction. if certain samples are < 5, reduce via below

#log_df = log_df.drop(log_df[log_df.next_activity == 'W_Afhandelen leads'].index)

# %% [markdown]
# Reduce Loops
#
# Function : `reduce_loops(df)`, Author: Manuel Camargo, Edited by: Bemali Wickramanayake

# %%
if experiment == 'No_Loops':
  log_df = reduce_loops(log_df)

# %% [markdown]
# #### Data Encoding and Vectorization

# %% [markdown]
# Index creating for data encoding
# Function : `create_index(log_df, column)`, Author: Manuel Camargo, Edited by: Bemali Wickramanayake

# %%
# Index creation for activity

ac_index = create_index(log_df, 'task')
index_ac = {v: k for k, v in ac_index.items()}

# Index creation for unit

rl_index = create_index(log_df, 'role')
index_rl = {v: k for k, v in rl_index.items()}

# Index creation for next activity

ne_index = create_index(log_df, 'next_activity')

index_ne = {v: k for k, v in ne_index.items()}

#mapping the dictionary values as columns in the dataframe
log_df['ac_index'] = log_df['task'].map(ac_index)
log_df['rl_index'] = log_df['role'].map(rl_index)
log_df['ne_index'] = log_df['next_activity'].map(ne_index)

print(rl_index)
print(index_rl)
log_df.head()
# Out:
# {'none': 0, 'role_         0': 1, 'role_     10124': 2, 'role_     10125': 3, 'role_     10138': 4, 'role_     10188': 5, 'role_     10228': 6, 'role_     10609': 7, 'role_     10629': 8, 'role_     10779': 9, 'role_     10789': 10, 'role_     10809': 11, 'role_     10861': 12, 'role_     10863': 13, 'role_     10881': 14, 'role_     10889': 15, 'role_     10899': 16, 'role_     10909': 17, 'role_     10910': 18, 'role_     10912': 19, 'role_     10913': 20, 'role_     10914': 21, 'role_     10929': 22, 'role_     10931': 23, 'role_     10932': 24, 'role_     10933': 25, 'role_     10935': 26, 'role_     10939': 27, 'role_     10972': 28, 'role_     10982': 29, 'role_     11000': 30, 'role_     11001': 31, 'role_     11002': 32, 'role_     11003': 33, 'role_     11009': 34, 'role_     11019': 35, 'role_     11049': 36, 'role_     11079': 37, 'role_     11119': 38, 'role_     11121': 39, 'role_     11122': 40, 'role_     11169': 41, 'role_     11179': 42, 'role_     11180': 43, 'role_     11181': 44, 'role_     11189': 45, 'role_     11201': 46, 'role_     11203': 47, 'role_     11259': 48, 'role_     11269': 49, 'role_     11289': 50, 'role_     11299': 51, 'role_     11300': 52, 'role_     11302': 53, 'role_     11304': 54, 'role_     11309': 55, 'role_     11319': 56, 'role_     11339': 57}
# {0: 'none', 1: 'role_         0', 2: 'role_     10124', 3: 'role_     10125', 4: 'role_     10138', 5: 'role_     10188', 6: 'role_     10228', 7: 'role_     10609', 8: 'role_     10629', 9: 'role_     10779', 10: 'role_     10789', 11: 'role_     10809', 12: 'role_     10861', 13: 'role_     10863', 14: 'role_     10881', 15: 'role_     10889', 16: 'role_     10899', 17: 'role_     10909', 18: 'role_     10910', 19: 'role_     10912', 20: 'role_     10913', 21: 'role_     10914', 22: 'role_     10929', 23: 'role_     10931', 24: 'role_     10932', 25: 'role_     10933', 26: 'role_     10935', 27: 'role_     10939', 28: 'role_     10972', 29: 'role_     10982', 30: 'role_     11000', 31: 'role_     11001', 32: 'role_     11002', 33: 'role_     11003', 34: 'role_     11009', 35: 'role_     11019', 36: 'role_     11049', 37: 'role_     11079', 38: 'role_     11119', 39: 'role_     11121', 40: 'role_     11122', 41: 'role_     11169', 42: 'role_     11179', 43: 'role_     11180', 44: 'role_     11181', 45: 'role_     11189', 46: 'role_     11201', 47: 'role_     11203', 48: 'role_     11259', 49: 'role_     11269', 50: 'role_     11289', 51: 'role_     11299', 52: 'role_     11300', 53: 'role_     11302', 54: 'role_     11304', 55: 'role_     11309', 56: 'role_     11319', 57: 'role_     11339'}
#    prefix_id  caseid                                          task  \
# 0   173736_6  173736  W_Filling in information for the application
# 1   173736_4  173736  W_Filling in information for the application
# 2   173736_5  173736  W_Filling in information for the application
# 3  173736_12  173736  W_Filling in information for the application
# 4   173736_1  173736  W_Filling in information for the application
#
#               role                end_timestamp                  trace_start  \
# 0  role_     11019  2011-10-01 23:40:09.6220000  2011-10-01 23:40:09.6220000
# 1  role_     11019  2011-10-01 23:40:09.6220000  2011-10-01 23:40:09.6220000
# 2  role_     11019  2011-10-01 23:40:09.6220000  2011-10-01 23:40:09.6220000
# 3  role_     11019  2011-10-01 23:40:09.6220000  2011-10-01 23:40:09.6220000
# 4  role_     11019  2011-10-01 23:40:09.6220000  2011-10-01 23:40:09.6220000
#
#    timelapsed                                      next_activity  \
# 0           0  W_Calling to add missing information to the ap...
# 1           0                        W_Calling after sent offers
# 2           0                        W_Assessing the application
# 3           0                        W_Assessing the application
# 4           0       W_Filling in information for the application
#
#                                            milestone  milestone_id  \
# 0                        W_Assessing the application             6
# 1                        W_Calling after sent offers             4
# 2                        W_Calling after sent offers             5
# 3  W_Calling to add missing information to the ap...            12
# 4       W_Filling in information for the application             1
#
#    task_index  prefix_length  ac_index  rl_index  ne_index
# 0           1              6         5        35         3
# 1           1              4         5        35         2
# 2           1              5         5        35         1
# 3           1             12         5        35         1
# 4           1              1         5        35         4

# %%
print(ne_index)
# Out:
# {'W_Assess fraud': 0, 'W_Assessing the application': 1, 'W_Calling after sent offers': 2, 'W_Calling to add missing information to the application': 3, 'W_Filling in information for the application': 4, 'W_Fixing incoming lead': 5}

# %% [markdown]
# Splitting the dataframe into test and train sets
#
# Function : `split_train_test(df, percentage)`, Author: Bemali Wickramanayake

# %%
# Split validation datasets
log_df_train, log_df_test = split_train_test(log_df, 0.3) # 70%/30%

# %% [markdown]
# Normalize Numerical Features
#
# Function : `normalize_events(log_df,args,numerical_features)`, Author: Manuel Camargo, Edited by: Bemali Wickramanayake

# %%
numerical_features = ['timelapsed']
log_df_train = normalize_events(log_df_train,args,numerical_features)
log_df_test = normalize_events(log_df_test,args,numerical_features)

# %%
training_traces = len(log_df_train['prefix_id'].unique())
test_traces = len(log_df_test['prefix_id'].unique())


print('Number of traces in training set is:'+str(training_traces))
print('Number of traces in test set is:'+str(test_traces))
# Out:
# Number of traces in training set is:29645
# Number of traces in test set is:12705

# %%
#Checking the Balance of the Dataset, by the target variable
print('training dataset')
print(log_df_train.groupby(['next_activity'])['prefix_id'].nunique())
print("")
print('test dataset')
print(log_df_test.groupby(['next_activity'])['prefix_id'].nunique())
print("")
# Out:
# training dataset
# next_activity
# W_Assess fraud                                               104
# W_Assessing the application                                 3664
# W_Calling after sent offers                                10849
# W_Calling to add missing information to the application     5117
# W_Filling in information for the application                9309
# W_Fixing incoming lead                                       602
# Name: prefix_id, dtype: int64
#
# test dataset
# next_activity
# W_Assess fraud                                               29
# W_Assessing the application                                1561
# W_Calling after sent offers                                4772
# W_Calling to add missing information to the application    2498
# W_Filling in information for the application               3658
# W_Fixing incoming lead                                      187
# Name: prefix_id, dtype: int64

# %% [markdown]
# Reformat events: converting the dataframe into a dictionary to aid vectorization
#
# Function : `reformat_events(log_df, ac_index, rl_index,ne_index)`, Author: Renuka Sindagatta/ Manuel Camargo, Edited by: Bemali Wickramanayake

# %%
log_train = reformat_events(log_df_train, ac_index, rl_index,ne_index)
log_test = reformat_events(log_df_test, ac_index, rl_index,ne_index)
#log_val = reformat_events(log_df_val, ac_index, rl_index,ne_index)

#print a sample of the dictionary
print(log_train[100])
# Out:
# {'caseid': '174159_5', 'ac_order': [5, 5, 5, 5, 5], 'rl_order': [42, 42, 41, 1, 38], 'tbtw': [-0.21829788624670257, -0.25245137483820124, -0.3307084741212214, -0.4275343993762311, -1.5367641542992445], 'next_activity': 4}

# %% [markdown]
# Vectorization: Convert the data dictionaries into trainable multi dimensional tensors
#
# Function: `vectorization(log,ac_index, rl_index, ne_index,trc_len,cases)` , Author: Bemali Wickramanayake, Inspired by the code of: Renuka Sindagatta

# %%
#Obtain the maximum trc_len and cases for each set

trc_len_train, cases_train = lengths(log_train)
trc_len_test, cases_test = lengths(log_test)
#trc_len_val, cases_val = lengths(log_val)

trc_len = max([trc_len_train, trc_len_test])

print("trace_length: "+str(trc_len)+", training cases: "+str(cases_train)+", test cases: "+str(cases_test) )
# Out:
# trace_length: 73, training cases: 29646, test cases: 12706

# %% [markdown]
# converting the training log (dictionary) into a Tensor

# %%
vec_train = vectorization(log_train,ac_index, rl_index, ne_index,trc_len,cases_train)
vec_test = vectorization(log_test,ac_index, rl_index, ne_index,trc_len,cases_test)
#vec_val = vectorization(log_val,ac_index, rl_index, ne_index,trc_len,cases_val)

# %%
vec_train['prefixes']['x_ac_inp']
# Out:
# array([[5., 0., 0., ..., 0., 0., 0.],
#        [5., 0., 0., ..., 0., 0., 0.],
#        [5., 5., 0., ..., 0., 0., 0.],
#        ...,
#        [3., 3., 3., ..., 0., 0., 0.],
#        [6., 0., 0., ..., 0., 0., 0.],
#        [5., 6., 0., ..., 0., 0., 0.]])

# %% [markdown]
# #### Generating Initial Embedding Weights for shared Model

# %%
ac_weights = to_categorical(sorted(index_ac.keys()), num_classes = len(ac_index))
ac_weights[0] = 0 # embedding weights for label none = 0

rl_weights =  to_categorical(sorted(index_rl.keys()), num_classes = len(rl_index))
rl_weights[0] = 0 # embeddig weights for label none = 0

# %%
# converting the weights 
weights = {'ac_weights':ac_weights, 'rl_weights':rl_weights, 'next_activity':len(ne_index)}

# converting the weights into a dictionary and saving
indexes = {'index_ac':index_ac, 'index_rl':index_rl,'index_ne':index_ne}

# converting the weights into a dictionary and saving
pre_index = {'ac_index':ac_index, 'rl_index':rl_index,'ne_index':ne_index}

# %% [markdown]
# ### Experiments

# %% [markdown]
# #### Load the Required Libraries

# %%
# !pip3 install pyflowchart
# Out:
# Requirement already satisfied: pyflowchart in c:\users\20182009\documents\master dsai\y2 q1\2imi00 seminar process analytics\replicationstudy\.venv\lib\site-packages (0.3.1)
# Requirement already satisfied: astunparse in c:\users\20182009\documents\master dsai\y2 q1\2imi00 seminar process analytics\replicationstudy\.venv\lib\site-packages (from pyflowchart) (1.6.3)
# Requirement already satisfied: chardet in c:\users\20182009\documents\master dsai\y2 q1\2imi00 seminar process analytics\replicationstudy\.venv\lib\site-packages (from pyflowchart) (5.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\20182009\documents\master dsai\y2 q1\2imi00 seminar process analytics\replicationstudy\.venv\lib\site-packages (from astunparse->pyflowchart) (0.41.2)
# Requirement already satisfied: six<2.0,>=1.6.1 in c:\users\20182009\documents\master dsai\y2 q1\2imi00 seminar process analytics\replicationstudy\.venv\lib\site-packages (from astunparse->pyflowchart) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import pickle
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import callbacks, Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model

import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from pyflowchart import *
import plotly.express as px

from models.shared import *
from models.specialised import *
from models.explain import *

# %% [markdown]
# #### shared Model

# %%
shared = shared_model(vec_train, weights, indexes, pre_index, args)

# %%
shared.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])
shared.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  ac_input (InputLayer)       [(None, 5)]                  0         []
#
#  rl_input (InputLayer)       [(None, 5)]                  0         []
#
#  ac_embedding (Embedding)    (None, 5, 7)                 49        ['ac_input[0][0]']
#
#  rl_embedding (Embedding)    (None, 5, 58)                3364      ['rl_input[0][0]']
#
#  t_input (InputLayer)        [(None, 5, 1)]               0         []
#
#  full_embs (Concatenate)     (None, 5, 66)                0         ['ac_embedding[0][0]',
#                                                                      'rl_embedding[0][0]',
#                                                                      't_input[0][0]']
#
#  dropout (Dropout)           (None, 5, 66)                0         ['full_embs[0][0]']
#
#  alpha (Bidirectional)       (None, 5, 100)               46800     ['dropout[0][0]']
#
#  alpha_dense (TimeDistribut  (None, 5, 1)                 101       ['alpha[0][0]']
#  ed)
#
#  beta (Bidirectional)        (None, 5, 100)               46800     ['dropout[0][0]']
#
#  timestep_attention (Softma  (None, 5, 1)                 0         ['alpha_dense[0][0]']
#  x)
#
#  feature_attention (TimeDis  (None, 5, 66)                6666      ['beta[0][0]']
#  tributed)
#
#  feature_importance (Multip  (None, 5, 66)                0         ['timestep_attention[0][0]',
#  ly)                                                                 'feature_attention[0][0]',
#                                                                      'dropout[0][0]']
#
#  lambda (Lambda)             (None, 66)                   0         ['feature_importance[0][0]']
#
#  dropout_1 (Dropout)         (None, 66)                   0         ['lambda[0][0]']
#
#  act_output (Dense)          (None, 6)                    402       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 104182 (406.96 KB)
# Trainable params: 104182 (406.96 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
batch_size = 128 # 32, 64, 128, 256
epochs = 250

# %%
shared_history = shared_model_fit(vec_train, shared, indexes, pre_index, MY_WORKSPACE_DIR, batch_size, epochs, args)
# Out:
# Epoch 1/250
# 197/197 [==============================] - 12s 23ms/step - loss: 1.0287 - accuracy: 0.7080 - val_loss: 0.5542 - val_accuracy: 0.8181 - lr: 0.0010
# Epoch 2/250
# 197/197 [==============================] - 3s 16ms/step - loss: 0.4419 - accuracy: 0.8304 - val_loss: 0.4261 - val_accuracy: 0.8239 - lr: 0.0010
# Epoch 3/250
# 197/197 [==============================] - 3s 17ms/step - loss: 0.3896 - accuracy: 0.8374 - val_loss: 0.4024 - val_accuracy: 0.8251 - lr: 0.0010
# Epoch 4/250
# 197/197 [==============================] - 3s 16ms/step - loss: 0.3756 - accuracy: 0.8380 - val_loss: 0.3994 - val_accuracy: 0.8161 - lr: 0.0010
# Epoch 5/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3646 - accuracy: 0.8398 - val_loss: 0.3939 - val_accuracy: 0.8165 - lr: 0.0010
# Epoch 6/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3617 - accuracy: 0.8396 - val_loss: 0.3861 - val_accuracy: 0.8311 - lr: 0.0010
# Epoch 7/250
# 197/197 [==============================] - 3s 16ms/step - loss: 0.3575 - accuracy: 0.8413 - val_loss: 0.3877 - val_accuracy: 0.8257 - lr: 0.0010
# Epoch 8/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3533 - accuracy: 0.8450 - val_loss: 0.3831 - val_accuracy: 0.8309 - lr: 0.0010
# Epoch 9/250
# 197/197 [==============================] - 3s 16ms/step - loss: 0.3502 - accuracy: 0.8433 - val_loss: 0.3814 - val_accuracy: 0.8233 - lr: 0.0010
# Epoch 10/250
# 197/197 [==============================] - 3s 16ms/step - loss: 0.3475 - accuracy: 0.8444 - val_loss: 0.3843 - val_accuracy: 0.8109 - lr: 0.0010
# Epoch 11/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3460 - accuracy: 0.8439 - val_loss: 0.3795 - val_accuracy: 0.8233 - lr: 0.0010
# Epoch 12/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3437 - accuracy: 0.8455 - val_loss: 0.3799 - val_accuracy: 0.8219 - lr: 0.0010
# Epoch 13/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3427 - accuracy: 0.8458 - val_loss: 0.3824 - val_accuracy: 0.8206 - lr: 0.0010
# Epoch 14/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3418 - accuracy: 0.8457 - val_loss: 0.3816 - val_accuracy: 0.8181 - lr: 0.0010
# Epoch 15/250
# 197/197 [==============================] - 4s 20ms/step - loss: 0.3403 - accuracy: 0.8480 - val_loss: 0.3827 - val_accuracy: 0.8318 - lr: 0.0010
# Epoch 16/250
# 197/197 [==============================] - 3s 17ms/step - loss: 0.3387 - accuracy: 0.8459 - val_loss: 0.3790 - val_accuracy: 0.8300 - lr: 0.0010
# Epoch 17/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3383 - accuracy: 0.8462 - val_loss: 0.3791 - val_accuracy: 0.8197 - lr: 0.0010
# Epoch 18/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3356 - accuracy: 0.8488 - val_loss: 0.3832 - val_accuracy: 0.8325 - lr: 0.0010
# Epoch 19/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3332 - accuracy: 0.8492 - val_loss: 0.3768 - val_accuracy: 0.8291 - lr: 0.0010
# Epoch 20/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3341 - accuracy: 0.8494 - val_loss: 0.3781 - val_accuracy: 0.8230 - lr: 0.0010
# Epoch 21/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3320 - accuracy: 0.8496 - val_loss: 0.3809 - val_accuracy: 0.8293 - lr: 0.0010
# Epoch 22/250
# 197/197 [==============================] - 4s 18ms/step - loss: 0.3305 - accuracy: 0.8505 - val_loss: 0.3873 - val_accuracy: 0.8224 - lr: 0.0010
# Epoch 23/250
# 197/197 [==============================] - 3s 17ms/step - loss: 0.3300 - accuracy: 0.8494 - val_loss: 0.3844 - val_accuracy: 0.8219 - lr: 0.0010
# Epoch 24/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3296 - accuracy: 0.8512 - val_loss: 0.3884 - val_accuracy: 0.8275 - lr: 0.0010
# Epoch 25/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3287 - accuracy: 0.8508 - val_loss: 0.3896 - val_accuracy: 0.8302 - lr: 0.0010
# Epoch 26/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3289 - accuracy: 0.8502 - val_loss: 0.3881 - val_accuracy: 0.8298 - lr: 0.0010
# Epoch 27/250
# 197/197 [==============================] - 3s 16ms/step - loss: 0.3261 - accuracy: 0.8515 - val_loss: 0.3909 - val_accuracy: 0.8246 - lr: 0.0010
# Epoch 28/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3241 - accuracy: 0.8523 - val_loss: 0.3928 - val_accuracy: 0.8172 - lr: 0.0010
# Epoch 29/250
# 197/197 [==============================] - 3s 15ms/step - loss: 0.3250 - accuracy: 0.8528 - val_loss: 0.3905 - val_accuracy: 0.8239 - lr: 0.0010

# %%
plot_shared(shared_history)

# %%
trained_model = os.path.join(os.path.join(MILESTONE_DIR, 'trained_models'),'shared_model_'+subset+'.h5')
shared.save(trained_model)
# Out:
# c:\Users\20182009\Documents\Master DSAI\y2 q1\2IMI00 seminar process analytics\replicationStudy\.venv\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ##### Load Saved Model and Evaluate

# %%
shared_trained_model = os.path.join(os.path.join(MILESTONE_DIR, 'trained_models'),'shared_model_'+subset+'.h5')
shared_model = load_model(shared_trained_model)

# %%
x_test,y_test = generate_inputs_shared(vec_test,args,indexes)

print("Evaluate on test data")

results = shared_model.evaluate(x_test, y_test, batch_size=batch_size)
y_pred_shared = shared_model.predict(x_test)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 100/100 [==============================] - 3s 6ms/step - loss: 0.3415 - accuracy: 0.8487
# 398/398 [==============================] - 3s 3ms/step
# test loss, test acc: [0.34146711230278015, 0.8486541509628296]

# %%
m1_y_test = y_test.argmax(axis=1)
m1_y_pred = y_pred_shared.argmax(axis=1)

# %% [markdown]
# Classification Report

# %%
target_names = [index_ne[i] for i in range(len(index_ne))]

print(classification_report(y_test.argmax(axis=1), y_pred_shared.argmax(axis=1), target_names=target_names))
# Out:
#                                                          precision    recall  f1-score   support
#
#                                          W_Assess fraud       0.73      0.66      0.69        29
#                             W_Assessing the application       0.82      0.60      0.70      1561
#                             W_Calling after sent offers       0.95      0.81      0.87      4773
# W_Calling to add missing information to the application       0.83      0.94      0.88      2498
#            W_Filling in information for the application       0.78      0.98      0.87      3658
#                                  W_Fixing incoming lead       0.65      0.23      0.34       187
#
#                                                accuracy                           0.85     12706
#                                               macro avg       0.79      0.70      0.72     12706
#                                            weighted avg       0.86      0.85      0.84     12706

# %% [markdown]
# Confusion Matrix

# %%
matrix = confusion_matrix(y_test.argmax(axis=1), y_pred_shared.argmax(axis=1))
print(matrix)
matrix_sum = np.sum(matrix, axis=1).reshape(-1,1)
matrix_perc = matrix / matrix_sum
df_cm = pd.DataFrame(matrix_perc, index = [index_ne[i] for i in range(len(index_ne))],
                  columns = [index_ne[i] for i in range(len(index_ne))])

plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
# Out:
# [[  19    4    1    3    1    1]
#  [   0  943  139  479    0    0]
#  [   0   45 3851    0  877    0]
#  [   0  160    2 2336    0    0]
#  [   0    0   45    0 3591   22]
#  [   7    0    0    0  137   43]]
# <Axes: >

# %% [markdown]
# #### specialised Model

# %%
specialised = specialised_model(vec_train, weights, indexes, pre_index, args)

# %%
specialised.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
specialised.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  ac_input (InputLayer)       [(None, 5, 7)]               0         []
#
#  rl_input (InputLayer)       [(None, 5, 58)]              0         []
#
#  t_input (InputLayer)        [(None, 5, 1)]               0         []
#
#  beta_ac (Bidirectional)     (None, 5, 100)               23200     ['ac_input[0][0]']
#
#  beta_rl (Bidirectional)     (None, 5, 100)               43600     ['rl_input[0][0]']
#
#  beta_t (Bidirectional)      (None, 5, 100)               20800     ['t_input[0][0]']
#
#  feature_attention_ac (Time  (None, 5, 7)                 707       ['beta_ac[0][0]']
#  Distributed)
#
#  feature_attention_rl (Time  (None, 5, 58)                5858      ['beta_rl[0][0]']
#  Distributed)
#
#  feature_attention_t (TimeD  (None, 5, 1)                 101       ['beta_t[0][0]']
#  istributed)
#
#  ac_importance (Multiply)    (None, 5, 7)                 0         ['feature_attention_ac[0][0]',
#                                                                      'ac_input[0][0]']
#
#  rl_importance (Multiply)    (None, 5, 58)                0         ['feature_attention_rl[0][0]',
#                                                                      'rl_input[0][0]']
#
#  t_importance (Multiply)     (None, 5, 1)                 0         ['feature_attention_t[0][0]',
#                                                                      't_input[0][0]']
#
#  concat (Concatenate)        (None, 5, 66)                0         ['ac_importance[0][0]',
#                                                                      'rl_importance[0][0]',
#                                                                      't_importance[0][0]']
#
#  alpha (Bidirectional)       (None, 5, 100)               46800     ['concat[0][0]']
#
#  alpha_dense (TimeDistribut  (None, 5, 1)                 101       ['alpha[0][0]']
#  ed)
#
#  timestep_attention (Softma  (None, 5, 1)                 0         ['alpha_dense[0][0]']
#  x)
#
#  multiply (Multiply)         (None, 5, 66)                0         ['timestep_attention[0][0]',
#                                                                      'concat[0][0]']
#
#  lambda_1 (Lambda)           (None, 66)                   0         ['multiply[0][0]']
#
#  dropout_2 (Dropout)         (None, 66)                   0         ['lambda_1[0][0]']
#
#  act_output (Dense)          (None, 6)                    402       ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 141569 (553.00 KB)
# Trainable params: 141569 (553.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
batch_size = 256 # 32, 64, 128, 256
epochs = 200

# %%
specialised_history = specialised_model_fit(vec_train, specialised, indexes, pre_index, MY_WORKSPACE_DIR, batch_size, epochs, args)
# Out:
# This is the output file path  c:\Users\20182009\Documents\Master DSAI\y2 q1\2IMI00 seminar process analytics\replicationStudy\Shared-and-Specialised-Attention-based-Interpretable-Models\BPIC12\models\model_specialised_All_{epoch:02d}-{val_loss:.2f}.h5
# Epoch 1/200
# 99/99 [==============================] - 20s 68ms/step - loss: 1.5960 - accuracy: 0.4416 - val_loss: 1.3823 - val_accuracy: 0.5844 - lr: 0.0010
# Epoch 2/200
# 99/99 [==============================] - 4s 39ms/step - loss: 1.2451 - accuracy: 0.6486 - val_loss: 1.1491 - val_accuracy: 0.6872 - lr: 0.0010
# Epoch 3/200
# 99/99 [==============================] - 4s 39ms/step - loss: 1.0431 - accuracy: 0.7485 - val_loss: 0.9545 - val_accuracy: 0.7697 - lr: 0.0010
# Epoch 4/200
# 99/99 [==============================] - 4s 40ms/step - loss: 0.9040 - accuracy: 0.7667 - val_loss: 0.8481 - val_accuracy: 0.7650 - lr: 0.0010
# Epoch 5/200
# 99/99 [==============================] - 4s 39ms/step - loss: 0.8220 - accuracy: 0.7752 - val_loss: 0.7802 - val_accuracy: 0.7765 - lr: 0.0010
# Epoch 6/200
# 99/99 [==============================] - 4s 44ms/step - loss: 0.7643 - accuracy: 0.7791 - val_loss: 0.7294 - val_accuracy: 0.7886 - lr: 0.0010
# Epoch 7/200
# 99/99 [==============================] - 4s 44ms/step - loss: 0.7211 - accuracy: 0.7845 - val_loss: 0.6884 - val_accuracy: 0.7942 - lr: 0.0010
# Epoch 8/200
# 99/99 [==============================] - 4s 44ms/step - loss: 0.6859 - accuracy: 0.7898 - val_loss: 0.6563 - val_accuracy: 0.8023 - lr: 0.0010
# Epoch 9/200
# 99/99 [==============================] - 4s 42ms/step - loss: 0.6555 - accuracy: 0.7947 - val_loss: 0.6287 - val_accuracy: 0.8064 - lr: 0.0010
# Epoch 10/200
# 99/99 [==============================] - 4s 39ms/step - loss: 0.6325 - accuracy: 0.7987 - val_loss: 0.6052 - val_accuracy: 0.8048 - lr: 0.0010
# Epoch 11/200
# 99/99 [==============================] - 4s 41ms/step - loss: 0.6078 - accuracy: 0.8015 - val_loss: 0.5845 - val_accuracy: 0.8077 - lr: 0.0010
# Epoch 12/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.5931 - accuracy: 0.8005 - val_loss: 0.5677 - val_accuracy: 0.8095 - lr: 0.0010
# Epoch 13/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.5714 - accuracy: 0.8033 - val_loss: 0.5526 - val_accuracy: 0.8095 - lr: 0.0010
# Epoch 14/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.5619 - accuracy: 0.8037 - val_loss: 0.5402 - val_accuracy: 0.8064 - lr: 0.0010
# Epoch 15/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.5508 - accuracy: 0.8044 - val_loss: 0.5292 - val_accuracy: 0.8082 - lr: 0.0010
# Epoch 16/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.5403 - accuracy: 0.8038 - val_loss: 0.5176 - val_accuracy: 0.8107 - lr: 0.0010
# Epoch 17/200
# 99/99 [==============================] - 4s 39ms/step - loss: 0.5298 - accuracy: 0.8073 - val_loss: 0.5094 - val_accuracy: 0.8118 - lr: 0.0010
# Epoch 18/200
# 99/99 [==============================] - 4s 40ms/step - loss: 0.5199 - accuracy: 0.8095 - val_loss: 0.5019 - val_accuracy: 0.8129 - lr: 0.0010
# Epoch 19/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.5071 - accuracy: 0.8127 - val_loss: 0.4944 - val_accuracy: 0.8120 - lr: 0.0010
# Epoch 20/200
# 99/99 [==============================] - 4s 40ms/step - loss: 0.5052 - accuracy: 0.8117 - val_loss: 0.4875 - val_accuracy: 0.8143 - lr: 0.0010
# Epoch 21/200
# 99/99 [==============================] - 4s 39ms/step - loss: 0.5001 - accuracy: 0.8133 - val_loss: 0.4832 - val_accuracy: 0.8120 - lr: 0.0010
# Epoch 22/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4924 - accuracy: 0.8132 - val_loss: 0.4825 - val_accuracy: 0.8084 - lr: 0.0010
# Epoch 23/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4880 - accuracy: 0.8137 - val_loss: 0.4747 - val_accuracy: 0.8136 - lr: 0.0010
# Epoch 24/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4857 - accuracy: 0.8133 - val_loss: 0.4687 - val_accuracy: 0.8161 - lr: 0.0010
# Epoch 25/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4803 - accuracy: 0.8144 - val_loss: 0.4692 - val_accuracy: 0.8091 - lr: 0.0010
# Epoch 26/200
# 99/99 [==============================] - 4s 40ms/step - loss: 0.4755 - accuracy: 0.8165 - val_loss: 0.4659 - val_accuracy: 0.8048 - lr: 0.0010
# Epoch 27/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4744 - accuracy: 0.8175 - val_loss: 0.4627 - val_accuracy: 0.8055 - lr: 0.0010
# Epoch 28/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4640 - accuracy: 0.8187 - val_loss: 0.4601 - val_accuracy: 0.8030 - lr: 0.0010
# Epoch 29/200
# 99/99 [==============================] - 4s 39ms/step - loss: 0.4663 - accuracy: 0.8165 - val_loss: 0.4545 - val_accuracy: 0.8118 - lr: 0.0010
# Epoch 30/200
# 99/99 [==============================] - 4s 39ms/step - loss: 0.4636 - accuracy: 0.8180 - val_loss: 0.4506 - val_accuracy: 0.8192 - lr: 0.0010
# Epoch 31/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4580 - accuracy: 0.8186 - val_loss: 0.4502 - val_accuracy: 0.8190 - lr: 0.0010
# Epoch 32/200
# 99/99 [==============================] - 4s 40ms/step - loss: 0.4542 - accuracy: 0.8195 - val_loss: 0.4495 - val_accuracy: 0.8091 - lr: 0.0010
# Epoch 33/200
# 99/99 [==============================] - 4s 42ms/step - loss: 0.4537 - accuracy: 0.8175 - val_loss: 0.4461 - val_accuracy: 0.8077 - lr: 0.0010
# Epoch 34/200
# 99/99 [==============================] - 4s 44ms/step - loss: 0.4487 - accuracy: 0.8210 - val_loss: 0.4409 - val_accuracy: 0.8163 - lr: 0.0010
# Epoch 35/200
# 99/99 [==============================] - 4s 42ms/step - loss: 0.4476 - accuracy: 0.8219 - val_loss: 0.4439 - val_accuracy: 0.8098 - lr: 0.0010
# Epoch 36/200
# 99/99 [==============================] - 4s 41ms/step - loss: 0.4436 - accuracy: 0.8227 - val_loss: 0.4388 - val_accuracy: 0.8143 - lr: 0.0010
# Epoch 37/200
# 99/99 [==============================] - 4s 39ms/step - loss: 0.4432 - accuracy: 0.8203 - val_loss: 0.4348 - val_accuracy: 0.8208 - lr: 0.0010
# Epoch 38/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4387 - accuracy: 0.8232 - val_loss: 0.4377 - val_accuracy: 0.8053 - lr: 0.0010
# Epoch 39/200
# 99/99 [==============================] - 4s 40ms/step - loss: 0.4319 - accuracy: 0.8255 - val_loss: 0.4339 - val_accuracy: 0.8161 - lr: 0.0010
# Epoch 40/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4309 - accuracy: 0.8249 - val_loss: 0.4331 - val_accuracy: 0.8071 - lr: 0.0010
# Epoch 41/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4307 - accuracy: 0.8249 - val_loss: 0.4315 - val_accuracy: 0.8170 - lr: 0.0010
# Epoch 42/200
# 99/99 [==============================] - 4s 39ms/step - loss: 0.4281 - accuracy: 0.8277 - val_loss: 0.4293 - val_accuracy: 0.8131 - lr: 0.0010
# Epoch 43/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4246 - accuracy: 0.8274 - val_loss: 0.4256 - val_accuracy: 0.8201 - lr: 0.0010
# Epoch 44/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4201 - accuracy: 0.8288 - val_loss: 0.4258 - val_accuracy: 0.8190 - lr: 0.0010
# Epoch 45/200
# 99/99 [==============================] - 4s 41ms/step - loss: 0.4182 - accuracy: 0.8267 - val_loss: 0.4237 - val_accuracy: 0.8192 - lr: 0.0010
# Epoch 46/200
# 99/99 [==============================] - 4s 40ms/step - loss: 0.4176 - accuracy: 0.8275 - val_loss: 0.4236 - val_accuracy: 0.8201 - lr: 0.0010
# Epoch 47/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4127 - accuracy: 0.8286 - val_loss: 0.4266 - val_accuracy: 0.8197 - lr: 0.0010
# Epoch 48/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4151 - accuracy: 0.8286 - val_loss: 0.4316 - val_accuracy: 0.8185 - lr: 0.0010
# Epoch 49/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4109 - accuracy: 0.8292 - val_loss: 0.4248 - val_accuracy: 0.8215 - lr: 0.0010
# Epoch 50/200
# 99/99 [==============================] - 4s 39ms/step - loss: 0.4087 - accuracy: 0.8299 - val_loss: 0.4248 - val_accuracy: 0.8221 - lr: 0.0010
# Epoch 51/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4065 - accuracy: 0.8314 - val_loss: 0.4243 - val_accuracy: 0.8242 - lr: 0.0010
# Epoch 52/200
# 99/99 [==============================] - 4s 40ms/step - loss: 0.4048 - accuracy: 0.8310 - val_loss: 0.4273 - val_accuracy: 0.8226 - lr: 0.0010
# Epoch 53/200
# 99/99 [==============================] - 4s 39ms/step - loss: 0.4036 - accuracy: 0.8315 - val_loss: 0.4240 - val_accuracy: 0.8228 - lr: 0.0010
# Epoch 54/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4014 - accuracy: 0.8319 - val_loss: 0.4295 - val_accuracy: 0.8217 - lr: 0.0010
# Epoch 55/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4016 - accuracy: 0.8324 - val_loss: 0.4306 - val_accuracy: 0.8233 - lr: 0.0010
# Epoch 56/200
# 99/99 [==============================] - 4s 38ms/step - loss: 0.4010 - accuracy: 0.8312 - val_loss: 0.4284 - val_accuracy: 0.8221 - lr: 5.0000e-04

# %%
plot_specialised(specialised_history)

# %%
trained_model = os.path.join(os.path.join(MILESTONE_DIR, 'trained_models'),'specialised_model_'+subset+'.h5')
specialised.save(trained_model)
# Out:
# c:\Users\20182009\Documents\Master DSAI\y2 q1\2IMI00 seminar process analytics\replicationStudy\.venv\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ##### Load Saved Model and Evaluate

# %%
trained_model = os.path.join(os.path.join(MILESTONE_DIR, 'trained_models'),'specialised_model_'+subset+'.h5')
specialised_model = load_model(trained_model)

# %% [markdown]
# Evaluating Prediction Performance

# %%
# Generating Inputs

x_test,y_test = generate_inputs(vec_test,args,indexes,experiment)

# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")

results = specialised_model.evaluate(x_test, y_test, batch_size=batch_size)
y_pred = specialised_model.predict(x_test)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 50/50 [==============================] - 3s 14ms/step - loss: 0.3867 - accuracy: 0.8376
# 398/398 [==============================] - 4s 5ms/step
# test loss, test acc: [0.38668715953826904, 0.8376357555389404]

# %%
target_names = [index_ne[i] for i in range(len(index_ne))]

print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1), target_names=target_names))
# Out:
#                                                          precision    recall  f1-score   support
#
#                                          W_Assess fraud       0.61      0.59      0.60        29
#                             W_Assessing the application       0.79      0.55      0.65      1561
#                             W_Calling after sent offers       0.96      0.80      0.87      4773
# W_Calling to add missing information to the application       0.80      0.93      0.86      2498
#            W_Filling in information for the application       0.77      0.99      0.87      3658
#                                  W_Fixing incoming lead       0.62      0.05      0.10       187
#
#                                                accuracy                           0.84     12706
#                                               macro avg       0.76      0.65      0.66     12706
#                                            weighted avg       0.85      0.84      0.83     12706

# %% [markdown]
# Confusion Matrix

# %%
matrix = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
print(matrix)
matrix_sum = np.sum(matrix, axis=1).reshape(-1,1)
matrix_perc = matrix / matrix_sum
df_cm = pd.DataFrame(matrix_perc, index = [index_ne[i] for i in range(len(index_ne))],
                  columns = [index_ne[i] for i in range(len(index_ne))])

plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True)
# Out:
# [[  17    6    0    3    3    0]
#  [   1  860  138  562    0    0]
#  [   0   44 3795    1  933    0]
#  [   0  174    0 2323    1    0]
#  [   1    0   11    2 3638    6]
#  [   9    0    0    0  168   10]]
# <Axes: >

# %%
m2_y_test = y_test.argmax(axis=1)
m2_y_pred = y_pred.argmax(axis=1)
st = pd.DataFrame({"y_test": m2_y_test, "m1_y_pred" : m1_y_pred, "m2_y_pred":m2_y_pred})
st.to_csv("st_W.csv")

import scipy.stats as stats
stats.ttest_ind(st['m1_y_pred'], st['m2_y_pred'])
# Out:
# TtestResult(statistic=-1.5970093343000036, pvalue=0.1102760614354038, df=25410.0)
